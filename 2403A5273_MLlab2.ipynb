# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/Heart_Disease_Prediction.csv')

# %%
print("First 5 rows:")
display(df.head())
# Out:
# First 5 rows:
#    Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 0   70    1                4  130          322             0            2
# 1   67    0                3  115          564             0            2
# 2   57    1                2  124          261             0            0
# 3   64    1                4  128          263             0            0
# 4   74    0                2  120          269             0            2
#
#    Max HR  Exercise angina  ST depression  Slope of ST  \
# 0     109                0            2.4            2
# 1     160                0            1.6            2
# 2     141                0            0.3            1
# 3     105                1            0.2            2
# 4     121                1            0.2            1
#
#    Number of vessels fluro  Thallium Heart Disease
# 0                        3         3      Presence
# 1                        0         7       Absence
# ...

# %%
print("Last 5 rows:")
display(df.tail())
# Out:
# Last 5 rows:
#      Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 265   52    1                3  172          199             1            0
# 266   44    1                2  120          263             0            0
# 267   56    0                2  140          294             0            2
# 268   57    1                4  140          192             0            0
# 269   67    1                4  160          286             0            2
#
#      Max HR  Exercise angina  ST depression  Slope of ST  \
# 265     162                0            0.5            1
# 266     173                0            0.0            1
# 267     153                0            1.3            2
# 268     148                0            0.4            2
# 269     108                1            1.5            2
#
#      Number of vessels fluro  Thallium Heart Disease
# 265                        0         7       Absence
# ...

# %%
num_rows, num_cols = df.shape
print(f"Number of rows: {num_rows}")
print(f"Number of columns: {num_cols}")
# Out:
# Number of rows: 270
# Number of columns: 14

# %%
print("Column Names:")
print(df.columns.tolist())
# Out:
# Column Names:
# ['Age', 'Sex', 'Chest pain type', 'BP', 'Cholesterol', 'FBS over 120', 'EKG results', 'Max HR', 'Exercise angina', 'ST depression', 'Slope of ST', 'Number of vessels fluro', 'Thallium', 'Heart Disease']

# %%
print("Dataset Information:")
df.info()
# Out:
# Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 270 entries, 0 to 269
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      270 non-null    int64
#  1   Sex                      270 non-null    int64
#  2   Chest pain type          270 non-null    int64
#  3   BP                       270 non-null    int64
#  4   Cholesterol              270 non-null    int64
#  5   FBS over 120             270 non-null    int64
#  6   EKG results              270 non-null    int64
#  7   Max HR                   270 non-null    int64
#  8   Exercise angina          270 non-null    int64
#  9   ST depression            270 non-null    float64
#  10  Slope of ST              270 non-null    int64
#  11  Number of vessels fluro  270 non-null    int64
#  12  Thallium                 270 non-null    int64
# ...

# %%
numerical_features = df.select_dtypes(include=['int64', 'float64']).columns.tolist()
categorical_features = df.select_dtypes(include=['object']).columns.tolist()

print("Numerical Features:", numerical_features)
print("Categorical Features:", categorical_features)
# Out:
# Numerical Features: ['Age', 'Sex', 'Chest pain type', 'BP', 'Cholesterol', 'FBS over 120', 'EKG results', 'Max HR', 'Exercise angina', 'ST depression', 'Slope of ST', 'Number of vessels fluro', 'Thallium']
# Categorical Features: ['Heart Disease']

# %%
print("Data types of all columns:")
print(df.dtypes)
# Out:
# Data types of all columns:
# Age                          int64
# Sex                          int64
# Chest pain type              int64
# BP                           int64
# Cholesterol                  int64
# FBS over 120                 int64
# EKG results                  int64
# Max HR                       int64
# Exercise angina              int64
# ST depression              float64
# Slope of ST                  int64
# Number of vessels fluro      int64
# Thallium                     int64
# Heart Disease               object
# dtype: object

# %%
print("Missing values per column:")
print(df.isnull().sum())
# Out:
# Missing values per column:
# Age                        0
# Sex                        0
# Chest pain type            0
# BP                         0
# Cholesterol                0
# FBS over 120               0
# EKG results                0
# Max HR                     0
# Exercise angina            0
# ST depression              0
# Slope of ST                0
# Number of vessels fluro    0
# Thallium                   0
# Heart Disease              0
# dtype: int64

# %%
print("Statistical summary of numerical features:")
display(df.describe())
# Out:
# Statistical summary of numerical features:
#               Age         Sex  Chest pain type          BP  Cholesterol  \
# count  270.000000  270.000000       270.000000  270.000000   270.000000
# mean    54.433333    0.677778         3.174074  131.344444   249.659259
# std      9.109067    0.468195         0.950090   17.861608    51.686237
# min     29.000000    0.000000         1.000000   94.000000   126.000000
# 25%     48.000000    0.000000         3.000000  120.000000   213.000000
# 50%     55.000000    1.000000         3.000000  130.000000   245.000000
# 75%     61.000000    1.000000         4.000000  140.000000   280.000000
# max     77.000000    1.000000         4.000000  200.000000   564.000000
#
#        FBS over 120  EKG results      Max HR  Exercise angina  ST depression  \
# count    270.000000   270.000000  270.000000       270.000000      270.00000
# mean       0.148148     1.022222  149.677778         0.329630        1.05000
# ...

# %%
age_mean = df['Age'].mean()
age_median = df['Age'].median()
age_std = df['Age'].std()

print(f"Mean Age: {age_mean:.2f}")
print(f"Median Age: {age_median:.2f}")
print(f"Standard Deviation of Age: {age_std:.2f}")
# Out:
# Mean Age: 54.43
# Median Age: 55.00
# Standard Deviation of Age: 9.11

# %%
min_cholesterol = df['Cholesterol'].min()
max_cholesterol = df['Cholesterol'].max()

print(f"Minimum Cholesterol: {min_cholesterol}")
print(f"Maximum Cholesterol: {max_cholesterol}")
# Out:
# Minimum Cholesterol: 126
# Maximum Cholesterol: 564

# %%
class_counts = df['Heart Disease'].value_counts()
print("Number of patients by disease status:")
print(class_counts)
# Out:
# Number of patients by disease status:
# Heart Disease
# Absence     150
# Presence    120
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.histplot(df['Age'],kde="true")
plt.title('Distribution of Age')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.grid(axis='y', alpha=0.75)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.histplot(df['Cholesterol'],kde="true")
plt.title('Distribution of Cholesterol Levels')
plt.xlabel('Cholesterol')
plt.ylabel('Frequency')
plt.grid(axis='y', alpha=0.75)
plt.show()

# %% [markdown]
# Age Distribution:
# The 'Age' distribution appears to be relatively normal, centered around the mean of 54.43 years and a median of 55.00 years. This indicates a general demographic of middle-aged to older patients in the dataset.
#
# Cholesterol Distribution:
# The 'Cholesterol' distribution shows values ranging from 126 to 564, with a visible concentration in the lower-to-mid range of this spectrum. While somewhat normal, it might exhibit a slight skew, indicating a subset of patients with higher cholesterol levels.
#
# Heart Disease Distribution:
# For the 'Heart Disease' outcome, the dataset shows 150 patients without heart disease ('Absence') and 120 patients with heart disease ('Presence'). This indicates a slightly imbalanced dataset, with more individuals not having heart disease.

# %%
correlation_matrix = df.corr(numeric_only=True)
print("Correlation Matrix:")
display(correlation_matrix)
# Out:
# Correlation Matrix:
#                               Age       Sex  Chest pain type        BP  \
# Age                      1.000000 -0.094401         0.096920  0.273053
# Sex                     -0.094401  1.000000         0.034636 -0.062693
# Chest pain type          0.096920  0.034636         1.000000 -0.043196
# BP                       0.273053 -0.062693        -0.043196  1.000000
# Cholesterol              0.220056 -0.201647         0.090465  0.173019
# FBS over 120             0.123458  0.042140        -0.098537  0.155681
# EKG results              0.128171  0.039253         0.074325  0.116157
# Max HR                  -0.402215 -0.076101        -0.317682 -0.039136
# Exercise angina          0.098297  0.180022         0.353160  0.082793
# ST depression            0.194234  0.097412         0.167244  0.222800
# Slope of ST              0.159774  0.050545         0.136900  0.142472
# Number of vessels fluro  0.356081  0.086830         0.225890  0.085697
# ...

# %%
import numpy as np

high_corr_threshold = 0.7
highly_correlated_pairs = []

# Get unique pairs of features
for i in range(len(correlation_matrix.columns)):
    for j in range(i):
        if abs(correlation_matrix.iloc[i, j]) > high_corr_threshold:
            col1 = correlation_matrix.columns[i]
            col2 = correlation_matrix.columns[j]
            correlation_value = correlation_matrix.iloc[i, j]
            highly_correlated_pairs.append((col1, col2, correlation_value))

if highly_correlated_pairs:
    print(f"Variables with absolute correlation greater than {high_corr_threshold}:")
    for col1, col2, corr_val in highly_correlated_pairs:
        print(f"- {col1} and {col2}: {corr_val:.2f}")
else:
    print(f"No variables found with absolute correlation greater than {high_corr_threshold}.")
# Out:
# No variables found with absolute correlation greater than 0.7.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.scatterplot(x='Age', y='Max HR', data=df)
plt.title('Scatter Plot of Age vs. Maximum Heart Rate')
plt.xlabel('Age')
plt.ylabel('Maximum Heart Rate')
plt.grid(True, linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# Age and Maximum Heart Rate (Max HR): As seen in the scatter plot and confirmed by a moderate negative correlation coefficient (-0.40), there's a clear trend where individuals tend to have a lower maximum heart rate as they age. This is a common physiological observation.
#
# Age and Number of Vessels Fluro: A moderate positive correlation (0.36) suggests that older individuals tend to have a higher 'Number of vessels fluro'. This could indicate an age-related increase in findings during fluoroscopy.
#
# ST Depression and Slope of ST: A strong positive correlation (0.61) exists between 'ST depression' and 'Slope of ST'. This indicates that these two cardiovascular diagnostic parameters tend to move in the same direction, suggesting they might be related manifestations of a similar underlying condition or measurement artifact.
#
# Sex and Thallium: There is a moderate positive correlation (0.39) between 'Sex' and 'Thallium' results. This suggests a notable difference in Thallium test outcomes based on the patient's sex
